# %%
import predict
import matplotlib.pyplot as plt
import pandas as pd

# %%
#data = predict.prepare_data('NSE-TATAGLOBAL11.csv')
#data = predict.prepare_data('AAPL.csv', ['timestamp', 'close'])
data = predict.prepare_data('GOOGL', distant=True, api_key='IEB6OPAXVXKW0L6B')
print(data.head())
plt.plot(data['Close'])
plt.show()
# Out:
#                  Date     Close
# 0 2019-07-16 09:35:00  1148.600
# 1 2019-07-16 09:40:00  1152.900
# 2 2019-07-16 09:45:00  1154.326
# 3 2019-07-16 09:50:00  1153.500
# 4 2019-07-16 09:55:00  1153.730

# %%
startAt = 1100
diff_order = 'return-price'
#diff_order = 1
diff_data = predict.differentiate(data, diff_order)
len(data)
data
# Out:
#                     Date      Close
# 0    2019-07-16 09:35:00  1148.6000
# 1    2019-07-16 09:40:00  1152.9000
# 2    2019-07-16 09:45:00  1154.3260
# 3    2019-07-16 09:50:00  1153.5000
# 4    2019-07-16 09:55:00  1153.7300
# 5    2019-07-16 10:00:00  1153.9200
# 6    2019-07-16 10:05:00  1151.6147
# 7    2019-07-16 10:10:00  1151.3900
# 8    2019-07-16 10:15:00  1151.6801
# 9    2019-07-16 10:20:00  1150.5300
# 10   2019-07-16 10:25:00  1151.2346
# 11   2019-07-16 10:30:00  1151.4950
# 12   2019-07-16 10:35:00  1153.4200
# 13   2019-07-16 10:40:00  1154.3800
# 14   2019-07-16 10:45:00  1156.3900
# 15   2019-07-16 10:50:00  1157.0000
# 16   2019-07-16 10:55:00  1156.1459
# 17   2019-07-16 11:00:00  1157.4950
# 18   2019-07-16 11:05:00  1155.6150
# 19   2019-07-16 11:10:00  1158.4510
# 20   2019-07-16 11:15:00  1157.3265
# 21   2019-07-16 11:20:00  1156.4200
# 22   2019-07-16 11:25:00  1155.8600
# 23   2019-07-16 11:30:00  1156.3600
# 24   2019-07-16 11:35:00  1157.7500
# ...

# %%
test = predict.max_profit(data, '2019-08-05 16:00:00', predict.linear_regression, periods=100)
test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ee678f64eb87> in <module>
# ----> 1 test = predict.max_profit(data, '2019-08-05 16:00:00', predict.linear_regression, periods=100)
#       2 test
#
# ~/Google Drive/stocks/previsions/predict.py in max_profit(data, buy_time, method, periods, **kwargs)
#     510 def max_profit(data, buy_time, method, periods, **kwargs):
#     511     startAt = data.index[data['Date'] == buy_time][0]
# --> 512     predictions = method(data, startAt, periods, **kwargs)
#     513     print('startAt = ', startAt)
#     514
#
# ~/Google Drive/stocks/previsions/predict.py in linear_regression(data, startAt, stopAt)
#     208     model.fit(x_train,y_train) # calculating coefficients
#     209
# --> 210     predictions = model.predict(x_valid) # Applies the regression
#     211
#     212     return predictions
#
# ...

# %%
data = data.append(pd.Series(), ignore_index=True)
data = data.append(pd.Series(), ignore_index=True)
data = data.append(pd.Series(), ignore_index=True)
data = data.append(pd.Series(), ignore_index=True)
data = data.append(pd.Series(), ignore_index=True)
data = data.append(pd.Series(), ignore_index=True)
data = data.append(pd.Series(), ignore_index=True)
data
# Out:
#                     Date      Close
# 0    2019-07-16 09:35:00  1148.6000
# 1    2019-07-16 09:40:00  1152.9000
# 2    2019-07-16 09:45:00  1154.3260
# 3    2019-07-16 09:50:00  1153.5000
# 4    2019-07-16 09:55:00  1153.7300
# 5    2019-07-16 10:00:00  1153.9200
# 6    2019-07-16 10:05:00  1151.6147
# 7    2019-07-16 10:10:00  1151.3900
# 8    2019-07-16 10:15:00  1151.6801
# 9    2019-07-16 10:20:00  1150.5300
# 10   2019-07-16 10:25:00  1151.2346
# 11   2019-07-16 10:30:00  1151.4950
# 12   2019-07-16 10:35:00  1153.4200
# 13   2019-07-16 10:40:00  1154.3800
# 14   2019-07-16 10:45:00  1156.3900
# 15   2019-07-16 10:50:00  1157.0000
# 16   2019-07-16 10:55:00  1156.1459
# 17   2019-07-16 11:00:00  1157.4950
# 18   2019-07-16 11:05:00  1155.6150
# 19   2019-07-16 11:10:00  1158.4510
# 20   2019-07-16 11:15:00  1157.3265
# 21   2019-07-16 11:20:00  1156.4200
# 22   2019-07-16 11:25:00  1155.8600
# 23   2019-07-16 11:30:00  1156.3600
# 24   2019-07-16 11:35:00  1157.7500
# ...

# %% [markdown]
# ---
# ## Moving Average

# %%
predictions = predict.moving_average(diff_data, startAt)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predict.plot_predictions(diff_data, predictions, startAt, diff_order=0, print_rms=True)

# %% [markdown]
# ---
# ## Linear Regression

# %%
predictions = predict.linear_regression(diff_data, startAt)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predict.plot_predictions(diff_data, predictions, startAt, diff_order=0, print_rms=True)

# %% [markdown]
# ---
# ## KNN

# %%
predictions = predict.knn(diff_data, startAt)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predict.plot_predictions(diff_data, predictions, startAt, diff_order=0, print_rms=True)

# %% [markdown]
# ---
# ## Prophet

# %%
predictions = predict.prophet(diff_data, startAt)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predict.plot_predictions(diff_data, predictions, startAt, diff_order=0, print_rms=True)

# %% [markdown]
# ---
# ## Auto-ARIMA
# _May take up to 10 minutes_

# %%
predictions = predict.arima_auto(diff_data, startAt)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predict.plot_predictions(diff_data, predictions, startAt, diff_order=0, print_rms=True)

# %% [markdown]
# ---
# ## SVM

# %%
predictions = predict.svm(diff_data, startAt)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predict.plot_predictions(diff_data, predictions, startAt, diff_order=0, print_rms=True)

# %% [markdown]
# ---
# ## MLP Regression

# %%
predictions = predict.MLPRegression(diff_data, startAt, hidden_layer_sizes=tuple([120]*10), activation='relu', solver='lbfgs', batch_size=350)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predict.plot_predictions(diff_data, predictions, startAt, diff_order=0, print_rms=True)

# %% [markdown]
# ___
# ## Theta Method
# *from m3 competition*

# %%
predictions = predict.theta_method(diff_data, startAt, alpha=0.12)
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)

# %%
predictions = predict.theta_method_2(diff_data, startAt, alpha=0.12)
del predictions[0]
predict.plot_predictions(data, predictions, startAt, diff_order=diff_order, print_rms=True)
